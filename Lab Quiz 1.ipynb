# %% [markdown]
# # CIS 517 Data Mining and Warehousing - Lab Quiz 1
# ### Total Marks: 7
#
# ### Instructions
#
# - Download the dataset file **`student_sleep_patterns.csv`** and place it in the same directory as this notebook.
# - Follow the questions **in order** and write your code in the provided sections.
# - Each question contains a coding task. Run the code to obtain the required values.
# - Your **final answers must be submitted in the Blackboard quiz**, not in this notebook.
# - Do **not** hard-code values. All answers must be generated through code execution.
# - Use the following libraries:
#   - `pandas`
#   - `numpy`
#   - `matplotlib`
#   - `seaborn`
#   - `scipy.stats`
#
# ### **What to Submit**
# 1. **This completed Jupyter notebook (.ipynb)** will be checked for correct code.
# 2. **Your numeric/MCQ answers must be entered in Blackboard**, which will be graded.
#
# ### **Important Notes**
# - Run all cells before submitting.
# - Keep your code clean and readable.
# - Plots must display clearly when required.

# %% [markdown]
# -----------
# In this quiz, you will be working with the **Student Sleep Patterns** dataset.
# Your task is to **read the data, explore it, and perform basic preprocessing** as instructed in each task.
# This exploration will help you understand factors that may influence students’ sleep quality.
#
# Before you begin, make sure to import all the necessary Python libraries you will use throughout the quiz

# %%
# Import needed libraries..

# %% [markdown]
# ## Task 1: Read the CSV into a DataFrame Called `sleep_df`
#
# Begin your analysis by loading the dataset into Python.
# Write Python code to read the CSV file and store it in a DataFrame named **`sleep_df`**.

# %%
# Read the CSV into a DataFrame Called sleep_df

# %% [markdown]
# ## Task 2: Find the Number of Rows in the Dataset
#
# To begin understanding the scale of our data, we first need to know how many student records are included in the dataset.
#
# Write Python code to determine **the total number of rows** in the DataFrame.

# %%
# Find the Number of Rows in the Dataset

# %% [markdown]
# ## Task 3: Add New Column "Sleep_Efficiency"
#
# Create a new column named `Sleep_Efficiency` in the DataFrame.
#
# This column represents the Sleep Efficiency Score, calculated using the formula:
#
# $$
# \text{Sleep Efficiency} = \frac{\text{Sleep Duration}}{\text{Screen Time +1}}
# $$

# %%
# Add New Column "Sleep_Efficiency"

# %% [markdown]
# ## Task 4: Explore Caffeine Intake Levels
#
# As part of exploring factors that may influence students’ sleep quality, we want to examine the variety of caffeine consumption patterns among students.
#
# Write Python code to determine **how many distinct Caffeine Intake levels** appear in the dataset.

# %%
# Explore Caffeine Intake Levels

# %% [markdown]
# ## Task 5: Filter Students Based on Sleep and Study Habits
#
# To further explore patterns related to student well-being, we want to identify students who maintain healthy sleep habits and consistent study routines.
#
# Write Python code to create a filtered DataFrame that includes only the students who:
#
# - sleep 7 hours or more, and
# - study for 2 hours.
#
# After creating this filtered DataFrame, determine **how many students meet both criteria**.

# %%
# Filter Students Based on Sleep and Study Habits

# %% [markdown]
# ## Task 6: Calculate the Average Sleep Duration
#
# Understanding the overall sleep behavior of students begins with examining basic summary statistics.
#
# Calculate the **mean (average) Sleep Duration** across all students in the dataset.

# %%
# Calculate the Average Sleep Duration

# %% [markdown]
# ## Task 7: Visualize the Relationship Between Sleep Duration and Academic Performance
#
# To better understand how sleep may affect student outcomes, we will examine the relationship between the number of hours students sleep and their academic performance.
#
# Create a scatterplot with:
# - `Sleep Duration` on the x-axis
# - `Academic Performance` on the y-axis

# %%
# Visualize Sleep Duration and Academic Performance
sns.scatterplot()
plt.title("Sleep Duration vs Academic_Performance")
plt.xlabel("Sleep Duration (hrs)")
plt.ylabel("Academic Performance (%)")
plt.show()

# %% [markdown]
# ## Task 8: Analyze Distribution and Calculate Probability
#
# Using the histogram titled **"Distribution of Screen Time Among Students"** shown below, determine the probability that a randomly selected student has **less than 3 hours of screen time** in a day.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of Screen Time
plt.figure(figsize=(8,5))
sns.histplot(sleep_df["Screen_Time"])

plt.title("Distribution of Screen Time Among Students")
plt.xlabel("Screen Time (hours)")
plt.ylabel("Count")

plt.show()

# %%
# Probability that screen time is less than 3 hours

# %% [markdown]
# ## Task 9: Convert Sleep Quality to a Proper Data Type
#
# During data preprocessing, it is important to ensure that attributes are stored in the correct format for analysis.
#
# Convert the `Sleep_Quality` column into a suitable data type so it can be used for calculations and further exploration.
# Any values that cannot be converted should automatically be replaced with `NaN`.

# %%
# Convert Sleep Quality to a Proper Data Type

# %% [markdown]
# ## Task 10: Count Missing Values in Sleep Quality
#
# After converting the `Sleep_Quality` column to a proper data type, some values may have become `NaN` if they were invalid.
#
# Write Python code to determine **how many rows** in the dataset contain a missing (`NaN`) value in the `Sleep_Quality` column.

# %%
# Count Missing Values in Sleep Quality

# %% [markdown]
# ## Task 11: Remove Rows Containing Missing Values
#
# To prepare the dataset for further analysis or modeling, it is often necessary to remove incomplete records.
#
# Write Python code to **remove any row that contains at least one `NaN` value** in the DataFrame.

# %%
# Remove Missing Values

# %% [markdown]
# ---
#
# ### End of Notebook
# Please make sure you have completed all tasks and **entered all required answers in the Blackboard quiz**.
#
# ---
