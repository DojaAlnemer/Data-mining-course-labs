# %% [markdown]
# # Lab 01 intro to python

# %% [markdown]
# ## Exploring gaps on my knowledge and practicing stuff

# %%
import numpy as np
import seaborn as sb

# %%
x = np.array([19])
x
# Out:
# array([19])

# %%
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Ensure you extract a single element from your array before performing this operation.

# %%
float(x)
x #outputs last line
# Out:
# C:\Users\daj_k\AppData\Local\Temp\ipykernel_23132\3407210515.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   float(x)
# array([19])

# %%
pyDataTypes = np.array(["int", "float", "str", "bool"]) #numpy array
print(pyDataTypes) # normalprint
# Out:
# ['int' 'float' 'str' 'bool']

# %%
pyDataTypes2 = ["int", "float", "str", "bool", "list"] #python list
pyDataTypes2
# Out:
# ['int', 'float', 'str', 'bool', 'list']

# %%
myList = [94, "how to ADHD", True, 44.44, pyDataTypes2] #Boolean values capitlize first letter
myList
# Out:
# [94, 'how to ADHD', True, 44.44, ['int', 'float', 'str', 'bool', 'list']]

# %%
myListOfLists = [[1, 2, 3], ["Doja", "2022", "tangerine"], [True, True, True, False], [9.99]] #no need to make equal size lists to make a list of lists
myListOfLists 
# tf the yellow color in the left means ??? oh its bcus i didnt execute this cell opsi
# Out:
# [[1, 2, 3], ['Doja', '2022', 'tangerine'], [True, True, True, False], [9.99]]

# %% [markdown]
# ## Subsetting lists (Extractin elements)

# %%
Top7Games = ["The witcher 3: wild hunt", "Minecraft", "Valorant", "Stardewvalley", "", "", "", "", "", ""] #list size 10
# intentional spaces

# %%
print(Top7Games)
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley', '', '', '', '', '', '']

# %%
print(Top7Games[:3]) #excluding [3], use normal human count to save ur braincells
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant']

# %%
print(Top7Games[:4])#excluding [4]
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley']

# %%
print(Top7Games[:10])
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley', '', '', '', '', '', '']

# %%
print(Top7Games[1:4]) # excluding [0] Including [3]...im on confusion. oh ! [start : end ] -> [inclusive : exclusive]
# Out:
# ['Minecraft', 'Valorant', 'Stardewvalley']

# %%
# let try again
print(Top7Games[4:10])
# Out:
# ['', '', '', '', '', '']

# %%
#what if 
print(Top7Games[4:11])
# Out:
# ['', '', '', '', '', '']

# %%
print(Top7Games[4:99])
# Out:
# ['', '', '', '', '', '']

# %%
print(Top7Games[4:-1]) #noice
# Out:
# ['', '', '', '', '']

# %%
print(Top7Games[:10]) # from start to finish
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley', '', '', '', '', '', '']

# %%
len(Top7Games) #instead of size() dont be silly
# Out:
# 10

# %%
Top4Games = Top7Games[:4]
Top4Games
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley']

# %%
NullGames = Top7Games[4:]
NullGames
# Out:
# ['', '', '', '', '', '']

# %%
print(Top7Games)
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley', '', '', '', '', '', '']

# %% [markdown]
# ## List Manipulation(ADD/DELETE/MODIFY)

# %%
print(Top7Games)
# Out:
# ['The witcher 3: wild hunt', 'Minecraft', 'Valorant', 'Stardewvalley', '', '', '', '', '', '']

# %%
Top7Games[2] = "CounterStrike"
Top7Games
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Top7Games[4:6] = ["Rust", "Vintage Story"]
Top7Games
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  'Rust',
#  'Vintage Story',
#  'Valorant',
#  '',
#  '',
#  '']

# %%
del Top7Games[6]
Top7Games
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  'Rust',
#  'Vintage Story',
#  '',
#  '']

# %%
del Top7Games[6:]
Top7Games
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  'Rust',
#  'Vintage Story']

# %%
Top7Games + ["Valorant", "LeagueOfLegends"]
Top7Games #why its not adding it to the list ? > needs reassignment of Top7Games
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  'Rust',
#  'Vintage Story']

# %%
len(Top7Games)
# Out:
# 6

# %%
Top7Games_ext=Top7Games + ["Valorant", "LeagueOfLegends"]
Top7Games_ext
# Out:
# ['The witcher 3: wild hunt',
#  'Minecraft',
#  'CounterStrike',
#  'Stardewvalley',
#  'Rust',
#  'Vintage Story',
#  'Valorant',
#  'LeagueOfLegends']

# %% [markdown]
# ## How to properly copy a list

# %%
list1 = ["a", "b", "c"]
list2 = list1 
list2 #this is a shallow copy, change in list 2 will apply in list1 ! meh
# Out:
# ['a', 'b', 'c']

# %%
list2[1] = "crossant"
print(list1)
# Out:
# ['a', 'crossant', 'c']

# %%
list3 = list(list1) #method 1
list3
# Out:
# ['a', 'crossant', 'c']

# %%
list3[0] = "creme brule"
list3[2] = "madeleine cake"
print(list1)
print(list3)
# Out:
# ['a', 'crossant', 'c']
# ['creme brule', 'crossant', 'madeleine cake']

# %%
list4 = list1[:] #method 2
list4
# Out:
# ['a', 'crossant', 'c']

# %%
list4[0] = "hot choco"
print(list1)
print(list2)
print(list3)
print(list4)
# Out:
# ['a', 'crossant', 'c']
# ['a', 'crossant', 'c']
# ['creme brule', 'crossant', 'madeleine cake']
# ['hot choco', 'crossant', 'c']

# %%
max(list1)
max(list2)
max(list3)
max(list4) #max string of last list #max(list1m list2, list3, list4)  < not valid #max = longest string
# Out:
# 'hot choco'

# %%
print(max(list1))
print(max(list2))
print(max(list3))
print(max(list4)) # max for each list
# Out:
# crossant
# crossant
# madeleine cake
# hot choco
